# %% [markdown]
# # PYTHON-15

# %% [markdown]
# ## 3 юнит

# %%
number = 2.5

# Проверяем, является ли число целым
print(number.is_integer())

# Представим как обыкновенную дробь
print(number.as_integer_ratio())
# 5/2=2,5
# Out:
# False
# (5, 2)

# %%
people = ['Vasiliy', 'Stanislav', 'Alexandra', 'Vasiliy']

# Подсчитываем, с помощью метода count
print(people.count('Vasiliy'))

# Отсортируем
people.sort()
print(people)
# Out:
# 2
# ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy']

# %%
# Проверим тип класса объекта number
print(number.__class__)

# Проверим тип класса объекта people
print(people.__class__)
# Out:
# <class 'float'>
# <class 'list'>

# %%
# Создадим пустой класс SalesReport
class SalesReport():
    pass

# %%
# Создадим объект по классу
report = SalesReport()

# Создадим другой объект по классу
report_2 = SalesReport()

# Это будут разные объекты
print(report == report_2)
print(report is report_2)
# Out:
# False
# False

# %% [markdown]
# ## 4 юнит

# %%
# Добавим новые атрибуты к объектам
report.amount = 10
report_2.amount = 20

# Создаем функцию для печати отчета
def print_report(report):
    print('Total amount:', report.amount)


# Печатаем отчеты
print_report(report)
print_report(report_2)
# Out:
# Total amount: 10
# Total amount: 20

# %%
# Положим функцию печати отчета внутрь класса — теперь это метод класса
class SalesReport():
    # Метод для печати отчета
    def print_report(self):
        print('Total amount:', self.amount)


# Пересоздадим объекты по новому классу и назначим атрибуты
report = SalesReport()
report.amount = 10
report_2 = SalesReport()
report_2.amount = 20

# Печатаем отчеты с помощью метода класса
report.print_report()
report_2.print_report()
# Out:
# Total amount: 10
# Total amount: 20

# %%
# Добавим еще методы к нашему классу
class SalesReport():

    # Позволим добавлять много разных сделок
    def add_deal(self, amount):
        # На первой сделке создадим список для хранения всех сделок
        if not hasattr(self, 'deals'):
            self.deals = []
        self.deals.append(amount)

    # Посчитаем сумму всех сделок
    def total_amount(self):
        return sum(self.deals)
    
    # Печатаем отчет с помощью метод класса
    def print_report(self):
        print('Total amount:', self.total_amount())


# Теперь мы можем добавлять несколько сделок и печатать отчет по ним
report = SalesReport()
report.add_deal(10_000)
report.add_deal(30_000)
report.print_report()
# Out:
# Total amount: 40000

# %%
# Задание 4.1

class DepartmentReport():
       
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        if not hasattr(self, 'revenues'):
            self.revenues = []
        self.revenues.append(amount)

    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        return sum(self.revenues)/len(self.revenues)


report = DepartmentReport()
report.add_revenue(1_000_000)
report.add_revenue(400_000)
print(report.revenues)
# [1000000, 400000]
print(report.average_revenue())
# 700000.0
# Out:
# [1000000, 400000]
# 700000.0

# %%
report = SalesReport()
# report.print_report()
# AttributeError: 'SalesReport' object has no attribute 'deals'

# %%
# Добавим метод инициализации для создания атрибута deals
class SalesReport():
    # Инициализируем список сделок при создании объекта класса
    def __init__(self):
        self.deals=[]

    # Позволим добавлять много разных сделок
    def add_deal(self, amount):
        self.deals.append(amount)

    # Посчитаем сумму всех сделок
    def total_amount(self):
        return sum(self.deals)
    
    # Печатаем отчет с помощью метод класса
    def print_report(self):
        print('Total amount:', self.total_amount())


# Ошибка AttributeError больше не возникает 
report = SalesReport()
print(report.deals)
print(report.total_amount())
# Out:
# []
# 0

# %%
# Будем принимать в __init__ ещё и имя менеджера  
class SalesReport():
    def __init__(self, manager_name):
        self.deals=[]
        self.manager_name=manager_name

    # Позволим добавлять много разных сделок
    def add_deal(self, amount):
        self.deals.append(amount)

    # Посчитаем сумму всех сделок
    def total_amount(self):
        return sum(self.deals)
    
    # Печатаем отчет с помощью метод класса
    def print_report(self):
        print('Manager', self.manager_name)
        print('Total amount:', self.total_amount())


report = SalesReport('Ivan Taranov')
report.add_deal(10_000)
report.add_deal(30_000)
report.print_report()
# Out:
# Manager Ivan Taranov
# Total amount: 40000

# %%
# Задание 4.2

class DepartmentReport():

    def __init__(self, company_name):
        """
        Метод инициализации класса. 
        Создаёт атрибуты revenues и company
        """
        self.revenues=[]
        self.company = company_name
    
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        self.revenues.append(amount)
    
    def average_revenue(self):
        """
        Вычисляет average_revenue — среднюю выручку по отделам — округляя до целого.
        Метод возвращает строку в формате:
        'Average department revenue for <company>: <average_revenue>'
        """
        average_revenue = sum(self.revenues)/len(self.revenues)
        return f'Average department revenue for {self.company}: {round(average_revenue)}'


report = DepartmentReport(company_name="Danon")
print(report.company)
# Danon

report.add_revenue(1_000_000)
report.add_revenue(400_000)

print(report.average_revenue())
# Average department revenue for Danon:
# Out:
# Danon
# Average department revenue for Danon: 700000

# %%
# Добавим ещё метрик в отчет

class SalesReport():
    def __init__(self, employee_name):
        self.deals=[]
        self.employee_name = employee_name

    def add_deal(self, company, amount):
        self.deals.append({'company': company, 'amount': amount})

    def total_amount(self):
        return sum([deal['amount'] for deal in self.deals])

    def average_deal(self):
        return self.total_amount()/len(self.deals)

    def all_companies(self):
        return (', ').join(list(set([deal['company'] for deal in self.deals])))

    def print_report(self):
        print('Employee:', self.employee_name)
        print('Total sales:', self.total_amount())
        print('Average sales:', self.average_deal())
        print('Companies:', self.all_companies())


report = SalesReport('Ivan Semenov')

report.add_deal('PepsiCo', 120_000)
report.add_deal('SkyEng', 250_000)
report.add_deal('PepsiCo', 20_000)

report.print_report()
# Out:
# Employee: Ivan Semenov
# Total sales: 390000
# Average sales: 130000.0
# Companies: SkyEng, PepsiCo

# %% [markdown]
# ## 5 юнит

# %%
# Класс клиент для оформления заказа
class Client():

    # Базовые данные
    def __init__(self, email, order_num, registration_year):
        self.email = email
        self.order_num = order_num
        self.registration_year = registration_year
        self.discount = 0

    # Оформление заказа
    def make_order(self, price):
        self.update_discount()
        self.order_num += 1

        # Здесь было бы оформление заказа, но мы просто выведем его цену
        discounted_price = price * (1 - self.discount)
        print(f'Order price for {self.email} is {discounted_price}')

    # Назначение скидки
    def update_discount(self):
        if self.registration_year < 2018 and self.order_num >= 5:
            self.discount = 0.1


# Создаем подобие базы данных
client_db = [
    Client('max@gmail.com', 2, 2019),
    Client('love@yandex.ru', 10, 2015),
    Client('german@sberbank.ru', 4, 2017)]

# Сгенерируем заказы
client_db[0].make_order(100)
client_db[1].make_order(200)
client_db[2].make_order(500)
client_db[2].make_order(500)
# Out:
# Order price for max@gmail.com is 100
# Order price for love@yandex.ru is 180.0
# Order price for german@sberbank.ru is 500
# Order price for german@sberbank.ru is 450.0

# %%
# Задание 5.1

# Создаем класс для хранения данных о пользователе и его балансе
class User():
    
    # Инициализируем базовые данные
    def __init__(self, email, password, balance):
        self.email = email
        self.password = password
        self.balance = balance

    # Метод для проверки логина и пароля
    def login(self, email, password):
        if self.email == email and self.password == password:
            return True
        else:
            return False

    # Метод для изменения баланса пользователя
    def update_balance(self, amount):
        self.balance += amount


# Создаем пользователя и проверяем его логин и баланс
user = User('gosha@roskino.org', 'qwerty', 20_000)

print(user.login('gosha@roskino.org', 'qwerty123'))
# False

print(user.login('gosha@roskino.org', 'qwerty'))
# True

user.update_balance(200)
user.update_balance(-500)

print(user.balance)
# 19700
# Out:
# False
# True
# 19700

# %%
import statistics


class DataFrame():
    
    def __init__(self, column, fill_value=0):
        # Инициализируем атрибуты
        self.column = column
        self.fill_value = fill_value
        self.fill_missed()  # заполняем пропущенные значения
        self.to_float()     # конвертируем все значения в числа

    def fill_missed(self):
        for i, value in enumerate(self.column):
            if value is None or value == '':
                self.column[i] = self.fill_value
    
    def to_float(self):
        self.column = [float(value) for value in self.column]
    
    def median(self):
        return statistics.median(self.column)
    
    def mean(self):
        return statistics.mean(self.column)
    
    def deviation(self):
        return statistics.stdev(self.column)


df = DataFrame(['1', 17, 4, None, 8])
print(df.column)
print(df.deviation())
print(df.mean())
# Out:
# [1.0, 17.0, 4.0, 0.0, 8.0]
# 6.892024376045111
# 6.0

# %%
# Задание 5.2

class IntDataFrame():
    
    def __init__(self, column):
        # В момент инициализации конвертируем все значения в целые числа
        self.column = [int(value) for value in column]
    
    # Метод для подсчёта количества не нулевых значений в колонке
    def count(self):
        return len(self.column) - self.column.count(0)

    # Метод для подсчёта количества уникальных значений в колонке
    def unique(self):
        return len(set(self.column))
        

df = IntDataFrame([4.7, 4, 3, 0, 2.4, 0.3, 4])
print(df.column)
print(df.count())
print(df.unique())
# Out:
# [4, 4, 3, 0, 2, 0, 4]
# 5
# 4

# %%
import pickle
from datetime import datetime
from os import path


# Класс для сохранения и загрузки данных
class Dumper():
    pass

    def __init__(self, archive_dir='archive/'):
        self.archive_dir = archive_dir

    # Сохраняем данные в файл
    def dump(self, data):
        with open(self.get_file_name(), 'wb') as file:
            pickle.dump(data, file)

    # Читаем данные из файла
    def load_for_day(self, day):
        file_name = path.join(self.archive_dir, day + '.pkl')
        with open(file_name, 'rb') as file:
            sets = pickle.load(file)
        return sets

    # Получаем имя файла для сохранения данных
    def get_file_name(self):
        today = datetime.now().strftime('%Y-%m-%d')
        return path.join(self.archive_dir, today + '.pkl')


# Данные для сохранения
data = {
    'performance': [10, 20, 10],
    'clients': {'Romashka': 10, 'Vector': 34}}

dumper = Dumper()

# Сохраняем данные в файл
dumper.dump(data)

# Восстанавливаем данные из файла для сегодня
file_name = datetime.now().strftime('%Y-%m-%d')
restored_data = dumper.load_for_day(file_name)
print(restored_data)
# Out:
# {'performance': [10, 20, 10], 'clients': {'Romashka': 10, 'Vector': 34}}

# %%
# Задание 5.3

# Класс сборщика технических логов
class OwnLogger():

    def __init__(self, logs={
        'info': None, 'warning': None,'error': None, 'all': None}):
        self.logs = logs

    # Метод для сохранения логов.
    # Он принимает сообщение и уровень, на который нужно сохранить лог
    def log(self, message, level):
        self.logs[level] = message
        self.logs['all'] = message

    # Метод для получения последнего лога по уровню.
    # Если уровень не указан, возвращает последний лог любого уровня
    def show_last(self, level='all'):
        return self.logs[level]


logger = OwnLogger()
logger.log('System started', 'info')
print(logger.show_last('error'))
# None

logger.log('Connection instable', 'warning')
logger.log('Connection lost', 'error')
print(logger.show_last())
# Connection lost
print(logger.show_last('info'))
# System started
# Out:
# None
# Connection lost
# System started

# %%
# Импортируем наши классы из других файлов
from helpers.dumper import Dumper
from helpers.data_frame import DataFrame
from helpers.client import Client

# %% [markdown]
# ## 6 юнит

# %%
# Задание 6.3

class Dog():

    def bark(*args):
        return 'Bark!'
    
    def give_paw(*args):
        return 'Paw'
