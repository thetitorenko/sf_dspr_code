# %% [markdown]
# # PYTHON-15

# %% [markdown]
# ## 3 юнит

# %%
number = 2.5

# Проверяем, является ли число целым
print(number.is_integer())

# Представим как обыкновенную дробь
print(number.as_integer_ratio())
# 5/2=2,5
# Out:
# False
# (5, 2)

# %%
people = ['Vasiliy', 'Stanislav', 'Alexandra', 'Vasiliy']

# Подсчитываем, с помощью метода count
print(people.count('Vasiliy'))

# Отсортируем
people.sort()
print(people)
# Out:
# 2
# ['Alexandra', 'Stanislav', 'Vasiliy', 'Vasiliy']

# %%
# Проверим тип класса объекта number
print(number.__class__)

# Проверим тип класса объекта people
print(people.__class__)
# Out:
# <class 'float'>
# <class 'list'>

# %%
# Создадим пустой класс SalesReport
class SalesReport():
    pass

# %%
# Создадим объект по классу
report = SalesReport()

# Создадим другой объект по классу
report_2 = SalesReport()

# Это будут разные объекты
print(report == report_2)
print(report is report_2)
# Out:
# False
# False

# %% [markdown]
# ## 4 юнит

# %%
# Добавим новые атрибуты к объектам
report.amount = 10
report_2.amount = 20

# Создаем функцию для печати отчета
def print_report(report):
    print('Total amount:', report.amount)


# Печатаем отчеты
print_report(report)
print_report(report_2)
# Out:
# Total amount: 10
# Total amount: 20

# %%
# Положим функцию печати отчета внутрь класса — теперь это метод класса
class SalesReport():
    # Метод для печати отчета
    def print_report(self):
        print('Total amount:', self.amount)


# Пересоздадим объекты по новому классу и назначим атрибуты
report = SalesReport()
report.amount = 10
report_2 = SalesReport()
report_2.amount = 20

# Печатаем отчеты с помощью метода класса
report.print_report()
report_2.print_report()

# %%
# Добавим еще методы к нашему классу
class SalesReport():

    # Позволим добавлять много разных сделок
    def add_deal(self, amount):
        # На первой сделке создадим список для хранения всех сделок
        if not hasattr(self, 'deals'):
            self.deals = []
        self.deals.append(amount)

    # Посчитаем сумму всех сделок
    def total_amount(self):
        return sum(self.deals)
    
    # Печатаем отчет с помощью метод класса
    def print_report(self):
        print('Total amount:', self.total_amount())


# Теперь мы можем добавлять несколько сделок и печатать отчет по ним
report = SalesReport()
report.add_deal(10_000)
report.add_deal(30_000)
report.print_report()
# Out:
# Total amount: 40000

# %%
# Задание 4.1

class DepartmentReport():
       
    def add_revenue(self, amount):
        """
        Метод для добавления выручки отдела в список revenues.
        Если атрибута revenues ещё не существует, метод должен создавать пустой список перед добавлением выручки.
        """
        if not hasattr(self, 'revenues'):
            self.revenues = []
        self.revenues.append(amount)
    
    def average_revenue(self):
        """
        Метод возвращает среднюю выручку по отделам.
        """
        return sum(self.revenues)/len(self.revenues)


report = DepartmentReport()
report.add_revenue(1_000_000)
report.add_revenue(400_000)
print(report.revenues)
# [1000000, 400000]
print(report.average_revenue())
# 700000.0
# Out:
# [1000000, 400000]
# 700000.0
